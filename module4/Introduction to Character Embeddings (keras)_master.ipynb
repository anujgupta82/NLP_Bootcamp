# %% [markdown]
# #### Agenda - Given a sequence of previous characters, model the probability distribution of the next character in the sequence.
#
# Here we try harry potter text
#
# We will be using kears for this note

# %%
from __future__ import print_function

import numpy as np
import random
import sys

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Get data

# %%
# load data
path = "./../data/harry_potter_3.txt"
text = open(path).read().lower()
print('corpus length:', len(text))
# Out:
# corpus length: 611606

# %%
total_chars = sorted(list(set(text)))
print('total chars:', len(total_chars))
# Out:
# total chars: 53

# %%
#dictionaries to map characters to IDs and vice-a-versa

char_indices = dict((c, i) for i, c in enumerate(total_chars))
indices_char = dict((i, c) for i, c in enumerate(total_chars))

# %%
# cut the text in semi-redundant sequences of maxlen characters

maxlen = 40 # length of data window
step = 1    # step by which to shift the data window 

sentences = []    # this stores X
next_chars = []   # this stores y

# (i:i+40) as X, (i+40) as corresponding y
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen]) # get sentence
    next_chars.append(text[i + maxlen])   # get next character
    

num_of_sentences = len(sentences)

print('Number of datapoints/sequences:', num_of_sentences)
# Out:
# Number of datapoints/sequences: 611566

# %%
#Vectorize the input 

# X will be a 3D tensor - num_of_sentences * maxlen * total_chars
# y will be 2D tensor - sentences * total_chars

print('Vectorization...')
X = np.zeros((num_of_sentences, maxlen, len(total_chars)), dtype=np.bool)
y = np.zeros((num_of_sentences, len(total_chars)), dtype=np.bool)

# populate the tensors
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Vectorization...

# %% [markdown]
# # Model

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()

# lstm takes a single slice of 3D tensor along num_of_sentences axiss
model.add(LSTM(128, input_shape=(maxlen, len(total_chars)))) 

# add a dense layer - takes 128 input and spits output of num_of_chars 
model.add(Dense(len(total_chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
#Preds is scores over output space (characters)
# Its nothing but - confidence the RNN currently assigns to each character coming next in the sequence

# we convert scores into probability distribution and pick the best bet. 

# Temperature. We can also play with the temperature of the Softmax during sampling. Decreasing the temperature 
# from 1 to some lower number (e.g. 0.5) makes the RNN more confident, but also more conservative in its samples. 
# Conversely, higher temperatures will give more diversity but at cost of more mistakes (e.g. spelling mistakes, 
# etc). In particular, setting temperature very near zero will give the most likely thing

def sample(preds, temperature=1.0):
    
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds) # convert scores to prob via softmax
    probas = np.random.multinomial(1, preds, 1)
    
    return np.argmax(probas) # return the one with max probability

# %%
for iteration in range(1, 60):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    model.fit(X, y,batch_size=128,epochs=1)
    
    start_index = random.randint(0, len(text) - maxlen - 1) # pick an index at random
    
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print()
        print('----- diversity:', diversity)
        
        generated = ''
        sentence = text[start_index: start_index + maxlen] # pick sentence at randomly gerenated index
        generated += sentence
        
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)
        sys.stdout.write("\n")
        
        for i in range(400):
            x = np.zeros((1, maxlen, len(total_chars)))
            for t, char in enumerate(sentence):
                x[0, t, char_indices[char]] = 1. # put the sentence in 1-hot format
                
            preds = model.predict(x, verbose=0)[0] # make the model spit out predictions
            
            next_index = sample(preds, diversity) # choose a character index
            next_char = indices_char[next_index]  # get the corresponding chracater
            
            generated += next_char                # append this character to the sentence
            sentence = sentence[1:] + next_char   # now shift the the sentence by one character
            
            sys.stdout.write(next_char)           # write the character to buffer
            sys.stdout.flush()
            
        print()
# Out:
# --------------------------------------------------
# Iteration 1
# Epoch 1/1
# 611566/611566 [==============================] - 810s 1ms/step - loss: 2.1640
#
# ----- diversity: 0.2
# ----- Generating with seed: "pine,
# and the book shivered, and then fe"
# pine,
# and the book shivered, and then fe
# et streak and she stright and the sure the she came and she was she harry, and she still the she streambeath the she con she streanst as the grimbed and she she the said and harry she sure the she care the gase the got in the gone the she could as the she carned the right and the give as his she said harry sure harry and as the she they she seeped the side and he starned the grase as the ginule th
#
# ----- diversity: 0.5
# ----- Generating with seed: "pine,
# and the book shivered, and then fe"
# pine,
# and the book shivered, and then fe
# et he wase got sevel the had the give get bus the shough the masick, in them the fere the sumpel and the stanter up as the gace the severing the snape where out then with then his starned with she seeped the give the suck the said siffer me suing and the ginage.
#
# "i seeple
# fould sheme the mattle said and stread snape, "in the gome the gon, and he wast the had starts falled his but of the shanked a
#
# ----- diversity: 1.0
# ----- Generating with seed: "pine,
# and the book shivered, and then fe"
# pine,
# and the book shivered, and then fe
# rmly winn
# to them visisp, aschight, and she ron he diectly? pecturded came."
#
# i wisel bat wirutessee
# entent money
# dlean. the nupthen face. "burginding
# regat, his untacy," said these ous theme all liminar. pinny
# a meck, itser she said reghap fubith the migne and
# shim. the sthenorimbousaing they.
#
# "cames one
# -- into nooree, she neal whos sith as
# cane --peenofelade then snew on topessoutsere harry,"
#
# ----- diversity: 1.2
# ----- Generating with seed: "pine,
# and the book shivered, and then fe"
# pine,
# and the book shivered, and then fe
# e, edemped a notser star had be hesespessousanglieveterted doob. thinglem heary do cestaned maght feech dught, fug lapecher.
#
# havched malfe and them,
# wand ngoran surched,
# all batty yos hean --"
# leck not, laugh
# sunch and that
# buci,
# yous?"
#
# "tupn thist blibbews to
# pisn seepcest. is her onlylunal
# felerfled all
# rearblanot y gostish, yeue,"
# balfon what?"
#
# coluping
# s malfered porpy a grnagge, lupinen
# fe
#
# --------------------------------------------------
# Iteration 2
# Epoch 1/1
# 611566/611566 [==============================] - 448s 732us/step - loss: 1.8079
#
# ----- diversity: 0.2
# ----- Generating with seed: ""very smart owl you've got there, chuckl"
# "very smart owl you've got there, chuckl
# y his the caster his his his hermione with th
# /home/piyush/Piyush/study/anthill/anthill/lib/python3.5/site-packages/ipykernel_launcher.py:15: RuntimeWarning: divide by zero encountered in log
#   from ipykernel import kernelapp as app
# e croum his his his his his him.
#
# "i chen his hermione harry was his his his here harry was his his his his harry cround hermione could his harry seen the caster his his hermione harry was hermione sumfref with the classide and hermione scabbers of his his hermione with the cast his hermione and hermione his harry could his his his him.
#
# "hermione seen
#
# ----- diversity: 0.5
# ----- Generating with seed: ""very smart owl you've got there, chuckl"
# "very smart owl you've got there, chuckl
# e. the farge his but they the crook.
#
# "hermione hermiously. "i have with the sit were his was the seemed on his his his see a dement was his his his here harry he had the
# was only, still his scabbers is with his with his his screak it. he son't cup in the bearly.
#
# "she wey with ammisging some streaked his his his me the having his a were come a had streaming atter the cup; he speen the back.
#
# "we'
#
# ----- diversity: 1.0
# ----- Generating with seed: ""very smart owl you've got there, chuckl"
# "very smart owl you've got there, chuckl
# e from the croffrankeling
# the clostly, you hime of at the fromby. were, up
# that dould whispiely. welled his is. i out abou vincrens. "the conion. she coured scoor wipe,
# lupin was inside.
#
# "abligh?" him what spearreas wiis. her mig up.
#
# hermione green membed ame is was would, his crowdiven he and --"
#
# but malfonts unwarr, to he have thatse croed duybled deeppesfor he have to can't
# sheg the fectoen.
#
# ----- diversity: 1.2
# ----- Generating with seed: ""very smart owl you've got there, chuckl"
# "very smart owl you've got there, chuckl
# y walts
# nite ope peirh the ryslenons," said the eresting azes.
#
# "scabbents
# feet hry sit..." ches, severer where, cumblen-enor and iningen on fill
# dawne spared yes. lupirly as
# to cailingnedentorlesswagrean pherunus the turney wey
# fimlves istank. wowh
# thud his co my but suping preflight," said harry bun hermioneam!"
#
# fick,
# wey tho popfers, wis smeffoces -- you this..."
#
# nevilsevecwagreat ron habrubl
#
# --------------------------------------------------
# Iteration 3
# Epoch 1/1
# 611566/611566 [==============================] - 436s 713us/step - loss: 1.7300
#
# ----- diversity: 0.2
# ----- Generating with seed: "ere was a pewter tankard almost as big
# a"
# ere was a pewter tankard almost as big
# a
# nd the care the come the stanted the chent the she was the should the wand the stant the stant the fire the got the from the comenon's the shard the start the comenon's the started the started the fire the chent the good the mane the care the stant the with the start the fire the chent the she was had stant the stant the stant the cared the good the started the the stant the come the chent the sta
#
# ----- diversity: 0.5
# ----- Generating with seed: "ere was a pewter tankard almost as big
# a"
# ere was a pewter tankard almost as big
# a
# nd from him stanted for the mane what the comenon's started the hall the serout him and he ground the stant unto but the comenoor had with and dight the time the find the ground the gopped the the finally could he was a lints the back.
#
# fire didn't exchank and hermione was fire he didn't on the ground the door littered the wand the firent the face at the didn't sharry to don't the stampear behind
#
# ----- diversity: 1.0
# ----- Generating with seed: "ere was a pewter tankard almost as big
# a"
# ere was a pewter tankard almost as big
# a
# n the slatch no the
# hippogrinkong at that moretling snape,
# and
# but he groong's that anto the from hea" strowe his betrousling
# defome. there's all the didn't cleaking i is his dood greaked the mind the
# very neadwaggenofe quite was herm off sire all grood
# points the yell -- moretain snapled yach and and hermione, their face
# mement. "he behind."
#
# "he looked that it'll there, what enclanky themmode fa
#
# ----- diversity: 1.2
# ----- Generating with seed: "ere was a pewter tankard almost as big
# a"
# ere was a pewter tankard almost as big
# a
# narment
# the drangrfong misn's wite it so that he sho lupin paclhacol of then ofte
# lar dumbledore unthing
# er ron! he mounl undredemorsh seen him ward
# room are instelling on handblece. then starthent me shad aunt must the gellora chanks.
#
# he hagwnrred trun bestaning ahsa.
# and fickthing onto the
# scare and shach was wongstishtref asstwors.
#
# grood.
#
# "and the tons. i come diom!" said mcrus caully.
# ladn'
#
# --------------------------------------------------
# Iteration 4
# Epoch 1/1
# 611566/611566 [==============================] - 436s 713us/step - loss: 2.0165
#
# ----- diversity: 0.2
# ----- Generating with seed: "rry's thoughts seemed to have shown on h"
# rry's thoughts seemed to have shown on h
# is thought the really them the stree the the they start the stree the thing the strent the great a stree the string the stree the stree the stood the scabbered they was and hermione was stroor the stood the stree was stree the strait of the stopt of the the was stree to the had so the stree's streaked the strate the stree so to the thing the back of the wand the strait and the strait of the stree
#
# ----- diversity: 0.5
# ----- Generating with seed: "rry's thoughts seemed to have shown on h"
# rry's thoughts seemed to have shown on h
# er strees so still it was sure that and the been her close the make them the black at that there the thought the
# was said the potterual to the gryffindor they try it of a greebed them the the a been to they and hermione really told croak.
#
# "you they said them the looked him start to the letione like they sure that to been out and and it to straithant
# who been them the string his tell thought and w
#
# ----- diversity: 1.0
# ----- Generating with seed: "rry's thoughts seemed to have shown on h"
# rry's thoughts seemed to have shown on h
# is an excicking shriasley
# on they'ch at our officloker, and he wood too time shricking in
# his alye vould the looks the
# was speet
# crunge off thingened a a tree?"
#
# "we're crooks harry's youring to booked been that slowrow sure were be spomention.
# teened and on a beard it berond.
#
# this start could turned than and harry were black. i tolt posaling word with if reds wo yours.
#
# not turned over at enormi
#
# ----- diversity: 1.2
# ----- Generating with seed: "rry's thoughts seemed to have shown on h"
# rry's thoughts seemed to have shown on h
# er heat with beand obceg tunurarnope snape
# was?"
# said ire in pe leging cointomingly fettor up scrass on on essiades
# -ew theck' from skiclion seat
# want of asmet themshanders. whoors... tult, our as it."
#
# hagrid bunger harry, soundss who who sext into at
# you be a somroak enermage, finied his back biting alongathed pretwe, comething sirder out who was it were ameteriget extery still that snapecly. wa
#
# --------------------------------------------------
# Iteration 5
# Epoch 1/1
# 611566/611566 [==============================] - 438s 716us/step - loss: 1.7477
#
# ----- diversity: 0.2
# ----- Generating with seed: "
# "excellent, harry," lupin muttered as h"
#
# "excellent, harry," lupin muttered as h
# e had and harry was could had had to and he had was shot the wizard the to the hand the to the store the to the to the to the was hermione to the she was the was harry shot the ground the stored the tight the shot of the came the to him the to the to the didn't to the shopt the shot to the to the to a malfoy to the to the was head to the store the to the hand of the hood the shot the she was the a
#
# ----- diversity: 0.5
# ----- Generating with seed: "
# "excellent, harry," lupin muttered as h"
#
# "excellent, harry," lupin muttered as h
# e had to with and the to to him and is the momean-thing wanded the hand and the didn't hermione the stole with of the teaked the less of ware her to had had shot and howeved to hood to the was didn't on the fight had didalf.
#
# the storcled to twike the to to and a magicul shoot quite midded his hand the didn't suck and harry wand of the hime the sidly to them to in the did of the thid old a did of
#
# ----- diversity: 1.0
# ----- Generating with seed: "
# "excellent, harry," lupin muttered as h"
#
# "excellent, harry," lupin muttered as h
# ad in the let.
#
# "you wanded, out. but dy day." you a hos'n't a retoc' well oll there under read, and show-wize, you hame lorlincol, break.
#
# landie magfoy dandish him shred, harry, momoum alreak in hand me, flat alt
# them die. thinklelv? harry burn ristle. momar and himing the hand me knower
# af groad, wood. "i last. o wiple stureded how ey, carew-pre you sumorted... he will pully, hiddid, oly herry
#
# ----- diversity: 1.2
# ----- Generating with seed: "
# "excellent, harry," lupin muttered as h"
#
# "excellent, harry," lupin muttered as h
# all, she jcops -- head and possince worder owided permiped a many
# magictoen, it, hope had tibviksest hor ord. aid one more. it soot i at mardy. gay swoedued thincy fully throut whe sucles, harry
# look take
# poote grown't looking a legry croakeghowed hime! a heem on dan them, loud with aloar dot
# gavew-whaurderabreean!
# ole croiret watteduadin dunthed olized sidgy
# and it knor nericulir, and harry i azk
#
# --------------------------------------------------
# Iteration 6
# Epoch 1/1
# 611566/611566 [==============================] - 435s 711us/step - loss: 3.2656
#
# ----- diversity: 0.2
# ----- Generating with seed: "inistry providing cars, father?" percy a"
# inistry providing cars, father?" percy a
# nd were wa store the doors was shously the stare the  the towar shously t the toward the dow of the toward the store the toward th st with a  the to the  the looked the stare the to the t the stare t   the to were and wh sit the were streared the  the towered the stare the was stare the toward the down the stare the stare the toward the c the moment the towered a to the stare the tow it of the sto
#
# ----- diversity: 0.5
# ----- Generating with seed: "inistry providing cars, father?" percy a"
# inistry providing cars, father?" percy a
# t the arri was should of the created the come it back was spey of the to the towrelithing th strawally. "weaded birks  and with allt the rearing closes, we so the dow becaured the everythinge everyfhanding the could to the were harry and the to ron th the a professor shree roulder and  the was the t a th the hear was reared wet welver and hermione toward, screaced here classiby. "we  out of but he
#
# ----- diversity: 1.0
# ----- Generating with seed: "inistry providing cars, father?" percy a"
# inistry providing cars, father?" percy a
# res
# efform of his bagbed wright, i year. whose  the mirs a know car was aske are a  but
#
# "vise, he' f net hut and surt a minong hurdeneruys his pink i so toward.
#
# " very bottorby, le's yo you've grints!" he dow  or inning arou ar they, with was wed as  brok bessic deet towlize he there's fudge.  and rike youre is him; it incraic wes choet ar the boy's see the had fize want e must brestlay.
#
# "felat
#
# ----- diversity: 1.2
# ----- Generating with seed: "inistry providing cars, father?" percy a"
# inistry providing cars, father?" percy a
# rinien.
#
# " the pen't truted," they've before. "er nossly
# glimsley's you've madaing mure. out then ratched in sverar
# ofly.
#
# harry  but roning, eane, telerera parnby!" horry clo there snat not peelvensesto dec shrous and
# welling,
#  papeuss againly -- at eed fach, hurrelten; by towaying a come aletlius, but them,
# right ritched brookshasser, the
# feck by"
#
# a magoy, hoooken furing the recky. the arasin t
#
# --------------------------------------------------
# Iteration 7
# Epoch 1/1
# 611566/611566 [==============================] - 434s 710us/step - loss: 7.3313
#
# ----- diversity: 0.2
# ----- Generating with seed: "t?"
#
# "with an incantation, which will wo"
# t?"
#
# "with an incantation, which will wo
#                                      to th )_ _                                toi       ( `  9  \  `           a     t  blo t 9 (_ _                           t s rou  e    0    `                       t  a rou   a    sa9   4  _                  t  a broi (  _   9   4   0                  t   toi   _           9  `                 a  toi         (  9  2 0                  f  trei 6            `
#
# ----- diversity: 0.5
# ----- Generating with seed: "t?"
#
# "with an incantation, which will wo"
# t?"
#
# "with an incantation, which will wo
#                                      sa bro t _  (    9  `                     f   got                                       fe ha)4_                               t  to th (9_                                 a seie th  3&                                 t toi    _          0                    t  a got  _                                    to th )_(                                 a bla fe  :`_
#
# ----- diversity: 1.0
# ----- Generating with seed: "t?"
#
# "with an incantation, which will wo"
# t?"
#
# "with an incantation, which will wo
#                                      to th 74 2                                so the( 3                                   hes s )\ 1  & 9 7  _  :                 t hes    : : _  9 4 _ _                  sai
#
# he  a 6(                            pat   ne*0 3         9           t          peia        9   6          l fere_9(                                f  dou sa  (   :   4    4
#
# ----- diversity: 1.2
# ----- Generating with seed: "t?"
#
# "with an incantation, which will wo"
# t?"
#
# "with an incantation, which will wo
#                                      te mere  2      :                          m a bure        _   `    (                 s tai  sai \ e  :   \ m                  o t  e siee   he0 1b    _  `                    f    caee  5&  :  )                         ou te                                 g  free ) &                                   extho  3                                   e fee  &4
#
# --------------------------------------------------
# Iteration 8
# Epoch 1/1
# 611566/611566 [==============================] - 437s 714us/step - loss: 13.6001
#
# ----- diversity: 0.2
# ----- Generating with seed: "for
# a year before lily and james died! y"
# for
# a year before lily and james died! y
#                                     to th (__                                 toi       9 &  ` _  _            t     t  to th )_                                  toi       ( 0  &  _  _           t     t  to th (_                                  toi       9 &  ` _  0            t     t  to th (_                                  to the4___                                  toi       9 `  _ _  `
#
# ----- diversity: 0.5
# ----- Generating with seed: "for
# a year before lily and james died! y"
# for
# a year before lily and james died! y
#                                     be th   9   3  9    0  9               g  s the  (( _ 2 `  )  ` _  0                 a care  (0 _    _    4                    a to th   _                                 a to th 4_7                                 toi       9 _  4 4  _            t     o  a do th()500 _                              toi       ) 4  9    _  0         t     o  broi             9
#
# ----- diversity: 1.0
# ----- Generating with seed: "for
# a year before lily and james died! y"
# for
# a year before lily and james died! y
#                                     hes s \_ 1  1 & 4 ( `  _                o teo  (4 _                              r a fee   2) _                             t bore h *47                             b   fia ea9                                w so  nee th   39                                p hes   (  (  _ 5 9  _                   ou th ( 1                             ta on th ( 2
#
# ----- diversity: 1.2
# ----- Generating with seed: "for
# a year before lily and james died! y"
# for
# a year before lily and james died! y
#                                     o tie    )1  7   9   `   &               a diee 7*                                bacai 7    9                           t  prot *                                     be nee  : 4 _      4   9                  fee      27                            e ou te                                    a was d     9  (  7                       toi   :    `  6 _ 7  9
#
# --------------------------------------------------
# Iteration 9
# Epoch 1/1
# 401408/611566 [==================>...........] - ETA: 2:38 - loss: 13.6000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-f787b8f1ebdf> in <module>()
#       3     print('-' * 50)
#       4     print('Iteration', iteration)
# ----> 5     model.fit(X, y,batch_size=128,epochs=1)
#       6
#       7     start_index = random.randint(0, len(text) - maxlen - 1) # pick an index at random
#
# ~/Piyush/study/anthill/anthill/lib/python3.5/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1035                                         initial_epoch=initial_epoch,
#    1036                                         steps_per_epoch=steps_per_epoch,
# -> 1037                                         validation_steps=validation_steps)
#    1038
#    1039     def evaluate(self, x=None, y=None,
#
# ~/Piyush/study/anthill/anthill/lib/python3.5/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# ~/Piyush/study/anthill/anthill/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2664                 return self._legacy_call(inputs)
#    2665
# -> 2666             return self._call(inputs)
#    2667         else:
#    2668             if py_any(is_tensor(x) for x in inputs):
#
# ~/Piyush/study/anthill/anthill/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2634                                 symbol_vals,
#    2635                                 session)
# -> 2636         fetched = self._callable_fn(*array_vals)
#    2637         return fetched[:len(self.outputs)]
#    2638
#
# ~/Piyush/study/anthill/anthill/lib/python3.5/site-packages/tensorflow/python/client/session.py in __call__(self, *args)
#    1449         if self._session._created_with_new_api:
#    1450           return tf_session.TF_SessionRunCallable(
# -> 1451               self._session._session, self._handle, args, status, None)
#    1452         else:
#    1453           return tf_session.TF_DeprecatedSessionRunCallable(
#
# KeyboardInterrupt:
