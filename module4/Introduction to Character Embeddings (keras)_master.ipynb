# %% [markdown]
# <a href="https://colab.research.google.com/github/anujgupta82/NLP_Bootcamp/blob/V_2_0/module4/Introduction%20to%20Character%20Embeddings%20(keras)_master.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Agenda - Given a sequence of previous characters, model the probability distribution of the next character in the sequence.
#
# Here we try harry potter text
#
# We will be using kears for this note

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# !mkdir -p drive
# !google-drive-ocamlfuse drive
# !ls /content/drive/*
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 131183 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.11-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.11-0ubuntu1~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.11-0ubuntu1~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.
#  /content/drive/2019_04_02_21_25_42.mp3
# '/content/drive/2019_04_11_22_01_00 (3ce053a2).mp3'
#  /content/drive/2019_04_11_22_01_00.mp3
#  /content/drive/2019_04_14_19_15_20.mp3
#  /content/drive/2019_06_19_21_37_06.mp3
#  /content/drive/continlonus.mp3
#  /content/drive/help.mp3
#  /content/drive/NLP_Bootcamp_codebase_status.desktop
#  /content/drive/nlphistory.txt
#  /content/drive/nytarticle.txt
#
# '/content/drive/Auto Call Recorder':
# All
#
# '/content/drive/Colab Notebooks':
# 'Copy of bag-of-words.ipynb'
# 'Copy of CharacterEmbedding_SkipGram (585d2fb1).ipynb'
# 'Copy of CharacterEmbedding_SkipGram.ipynb'
# 'Copy of doc2vec PV-DBOW Distributed Bag of Words version of Paragraph Vector.ipynb'
# 'Copy of doc2vec PV-DM Distributed Memory version of Paragraph Vector (1d49939f).ipynb'
# 'Copy of doc2vec PV-DM Distributed Memory version of Paragraph Vector (47ce74b2).ipynb'
# 'Copy of doc2vec PV-DM Distributed Memory version of Paragraph Vector (b44c69fc).ipynb'
# 'Copy of doc2vec PV-DM Distributed Memory version of Paragraph Vector.ipynb'
# 'Copy of Introduction to Character Embeddings (keras).ipynb'
# 'Copy of Introduction to Character Embeddings (keras)_master (764a9c3a).ipynb'
# 'Copy of Introduction to Character Embeddings (keras)_master.ipynb'
# 'Copy of N-gram (a78598d1).ipynb'
# 'Copy of N-gram.ipynb'
# 'Copy of SkipGram_barebones_wiki (2f5da025).ipynb'
# 'Copy of SkipGram_barebones_wiki (429e8042).ipynb'
# 'Copy of SkipGram_barebones_wiki (8b2b576a).ipynb'
# 'Copy of SkipGram_barebones_wiki (a39d018e).ipynb'
# 'Copy of SkipGram_barebones_wiki.ipynb'
# 'Copy of skip-thoughts original paper implementation.ipynb'
# 'Copy of textacy-MY'
# 'Copy of t-SNE Fallacies.ipynb'
# 'Copy of Tweet2Vec.ipynb'
# 'Copy of Untitled3.ipynb'
# 'Copy of word2vec_glove_model_tensorflow.ipynb'
# 'Copy of word2vec_skip_gram_model.ipynb'
#  ENTITY_LINKING
#  EntityLinking-AzureTextAnalytics.ipynb
# 'KPE (b603411b).ipynb'
#  KPE.ipynb
#  LEARNING_PANDAS.ipynb
#  MUSCLE-NEW-1.ipynb
#  N-gram.ipynb
#  SPACY
#  textacy
#  textacy-MY
#  Untitled0.ipynb
#  Untitled1.ipynb
#  Untitled2.ipynb
#  Untitled3.ipynb
#  Untitled4.ipynb
#  Untitled5.ipynb
#  Untitled6.ipynb
#  Untitled7.ipynb
#  Untitled8.ipynb
#
# /content/drive/GoogleDrive_Utils:
# load_imdb_data.py  __pycache__	readWikiData.py  tsne_python
#
# /content/drive/NLP_bootcamp:
# Data

# %%
from __future__ import print_function

import numpy as np
import random
import sys

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Get data

# %%
# load data
path = "/content/drive/NLP_bootcamp/Data/harry_potter_3.txt"
text = open(path).read().lower()
print('corpus length:', len(text))
# Out:
# corpus length: 611606

# %%
total_chars = sorted(list(set(text)))
print('total chars:', len(total_chars))
# Out:
# total chars: 53

# %%
#dictionaries to map characters to IDs and vice-a-versa

char_indices = dict((c, i) for i, c in enumerate(total_chars))
indices_char = dict((i, c) for i, c in enumerate(total_chars))

# %%
# cut the text in semi-redundant sequences of maxlen characters

maxlen = 40 # length of data window
step = 1    # step by which to shift the data window 

sentences = []    # this stores X
next_chars = []   # this stores y

# (i:i+40) as X, (i+40) as corresponding y
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen]) # get sentence
    next_chars.append(text[i + maxlen])   # get next character
    

num_of_sentences = len(sentences)

print('Number of datapoints/sequences:', num_of_sentences)
# Out:
# Number of datapoints/sequences: 611566

# %%
#Vectorize the input 

# X will be a 3D tensor - num_of_sentences * maxlen * total_chars
# y will be 2D tensor - sentences * total_chars

print('Vectorization...')
X = np.zeros((num_of_sentences, maxlen, len(total_chars)), dtype=np.bool)
y = np.zeros((num_of_sentences, len(total_chars)), dtype=np.bool)

# populate the tensors
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Vectorization...

# %% [markdown]
# # Model

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()

# lstm takes a single slice of 3D tensor along num_of_sentences axiss
model.add(LSTM(128, input_shape=(maxlen, len(total_chars)))) 

# add a dense layer - takes 128 input and spits output of num_of_chars 
model.add(Dense(len(total_chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# Build model...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
#Preds is scores over output space (characters)
# Its nothing but - confidence the RNN currently assigns to each character coming next in the sequence

# we convert scores into probability distribution and pick the best bet. 

# Temperature. We can also play with the temperature of the Softmax during sampling. Decreasing the temperature 
# from 1 to some lower number (e.g. 0.5) makes the RNN more confident, but also more conservative in its samples. 
# Conversely, higher temperatures will give more diversity but at cost of more mistakes (e.g. spelling mistakes, 
# etc). In particular, setting temperature very near zero will give the most likely thing

def sample(preds, temperature=1.0):
    
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds) # convert scores to prob via softmax
    probas = np.random.multinomial(1, preds, 1)
    
    return np.argmax(probas) # return the one with max probability

# %%
for iteration in range(1, 60):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    model.fit(X, y,batch_size=128,epochs=1)
    
    start_index = random.randint(0, len(text) - maxlen - 1) # pick an index at random
    
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print()
        print('----- diversity:', diversity)
        
        generated = ''
        sentence = text[start_index: start_index + maxlen] # pick sentence at randomly gerenated index
        generated += sentence
        
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)
        sys.stdout.write("\n")
        
        for i in range(400):
            x = np.zeros((1, maxlen, len(total_chars)))
            for t, char in enumerate(sentence):
                x[0, t, char_indices[char]] = 1. # put the sentence in 1-hot format
                
            preds = model.predict(x, verbose=0)[0] # make the model spit out predictions
            
            next_index = sample(preds, diversity) # choose a character index
            next_char = indices_char[next_index]  # get the corresponding chracater
            
            generated += next_char                # append this character to the sentence
            sentence = sentence[1:] + next_char   # now shift the the sentence by one character
            
            sys.stdout.write(next_char)           # write the character to buffer
            sys.stdout.flush()
            
        print()
# Out:
# --------------------------------------------------
# Iteration 1
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# Epoch 1/1
# 611566/611566 [==============================] - 485s 793us/step - loss: 1.6931
#
# ----- diversity: 0.2
# ----- Generating with seed: "nagall,
# aren't you, harry?"
#
# "no, i'm no"
# nagall,
# aren't you, harry?"
#
# "no, i'm no
# t the grabbed the grip the stand and harry was a start the gray the start the stand the gringers and harry and hermione standing the cased the door and the door to have been black and hermione was a grinning at the disappeared the starting harry was a start the starting the dark arts and the dementors and the dementors and they was a start the door and the dementors was a talking the starting the
#
# ----- diversity: 0.5
# ----- Generating with seed: "nagall,
# aren't you, harry?"
#
# "no, i'm no"
# nagall,
# aren't you, harry?"
#
# "no, i'm no
# t it was in the wand over the ward the light, harry was behind the saw that was all moment out of the dementors for it until was to the ward me and they and they and hermione dleeped the faw what a dementors and the lay of harry and gringer have said, and they seemed to some cloak as an at about harry and the wardeling a points and head and the lin out his mouth.
#
# "well, black relly look an of bla
#
# ----- diversity: 1.0
# ----- Generating with seed: "nagall,
# aren't you, harry?"
#
# "no, i'm no"
# nagall,
# aren't you, harry?"
#
# "no, i'm no
# t
# about that i becast, sog, they air it body han icensapteting wationt your disasn't
# mund... and two fell of theyfore cole bott, had mady unbiquithed, didn't had betropking. looking and nervous.
# a seaved
# that palents. they
# were from your
# fooe his class, and put her zeark snape.
#
# "creeking that how have caman turn to going anyoleon even awnew speents. greatouss's so who
# wenter. what latten take!"
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "nagall,
# aren't you, harry?"
#
# "no, i'm no"
# nagall,
# aren't you, harry?"
#
# "no, i'm no
# w?" harry tronaeded black repliddy, anyoned. "onery, over yourscreace diuntere ?"
#
# "he cup all oir.
#
# "cluvty is twairel ne'd agave expe?" onooply. "tiqushoty?"
#
# "i that harry's out of ih asuseut overy awighting classop the broom timed 'is out -- they keep anyoniod some po?d they relippefel mrieved all ab? and harry de
# uud, hut muver the coattion, one of everything just afreewing bed, and waotysaed
#
# --------------------------------------------------
# Iteration 2
# Epoch 1/1
# 611566/611566 [==============================] - 485s 793us/step - loss: 1.4554
#
# ----- diversity: 0.2
# ----- Generating with seed: "to ask for more time;
# everyone else was "
# to ask for more time;
# everyone else was
# all the dark arts and the weasless of his face and the castle and harry, and hermione was started the hands and hermione took and hermione was staring at the wall, and he was a loud the station, and he was a way, he had been and hermione, hermione was a first the whoment off the weaking and and hermione was a back to her mouth, he had been and hermione and he was a chance and the looking the face.
#
# ----- diversity: 0.5
# ----- Generating with seed: "to ask for more time;
# everyone else was "
# to ask for more time;
# everyone else was
# all the his wand.
#
# "it was a chance of him," said harry.
#
# "who in hogsmeade," said harry to the back toward the ground to the face to gryffindor tears and a chance and the d
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in log
# isturie and the great and hermione down the staring and
# wood toward
# excelling in the wall. harry saw the face and the possible of the table, who was they saw anything table and they waid the before harry and hermione poened bat
#
# ----- diversity: 1.0
# ----- Generating with seed: "to ask for more time;
# everyone else was "
# to ask for more time;
# everyone else was
# now
# cloak pogching table, rolled "walk yelleal." harry said on socerhawry last across the dark,
# looking.
#
# "ron," said hermionely.
#
# "shot," said harry.
#
# "didn't mausivet -- de'n the throught's lin
# w. filing, but you'd parned ; it as it, heard dear! does frelling grinnaticapum when the hoaches
# the fhou. the gleasorib'
# longwahograin.
#
# "where has we slong to be stoppey that not air, it's comabs,.... h
#
# ----- diversity: 1.2
# ----- Generating with seed: "to ask for more time;
# everyone else was "
# to ask for more time;
# everyone else was
# spinted the lapt tod quge
# wiped would open naille garges, and harry and and the
# ean's wrete,
# hunding reating against muggon.
#
# parched she and he disapperas matche, most the
# heathing stoppe cubre's slap as all
# the,
# pleasaed entr he strange, too.
#
# round meabeled,
# swould s
# force that, duffelich
# mind from ut the bedreenehly dormust marwa... "yoo," puely hopees.
#
# numball's hand?"
#
# "no, inpected -- i te
#
# --------------------------------------------------
# Iteration 3
# Epoch 1/1
# 611566/611566 [==============================] - 486s 795us/step - loss: 1.4080
#
# ----- diversity: 0.2
# ----- Generating with seed: "ayed to a halt,
# and hermione and ron got"
# ayed to a halt,
# and hermione and ron got
#  out of the stairs with the staircase and the window of the staircase with the staircase to be a look of the stomack was because to see her was with the more of the stomack was the staircase of the stairs with him off the wardrogon the only was the tracking at him and had this was the way of the window of the stairs of his was and staring at the staircase with him and harry was a brandy and a both
#
# ----- diversity: 0.5
# ----- Generating with seed: "ayed to a halt,
# and hermione and ron got"
# ayed to a halt,
# and hermione and ron got
#  the stair in his hand
# and set on the hoppogriff toward harry on checking and leaving and the firebolt.
#
# "there was a cheering, ron, and it was star defense of his standing of about so potter was with the firebord to see he was seemed to have to see harry was was to stare on the window a follow on the wardrable where the hogwarts.
#
# "but i'm move to know it -- and ron," said harry, was then happeni
#
# ----- diversity: 1.0
# ----- Generating with seed: "ayed to a halt,
# and hermione and ron got"
# ayed to a halt,
# and hermione and ron got
# .
#
# "forward you --"
#
# "i no, he -- hopped hogsmeade are voice,
# the youpul on know staring only belied i aoming for the trais with "where's thank at steps they almost's a it?"
#
# "my eaty away it. all again?" lupin belody.
#
# "how didn't come or braked... harry," said madam moon a take say he poing away neville
# madam hoochag of wearing towored itullybony's fielre.
# "it was faint to patus, a rinner -- "is
#
# ----- diversity: 1.2
# ----- Generating with seed: "ayed to a halt,
# and hermione and ron got"
# ayed to a halt,
# and hermione and ron got
# s. it"soickly-tuguitaley, strode neck,
# it was lore whet closer. this have seemed to
# bedlinger pafes,
# scream, happecemeds high,
# how heard him -- monthavedwiling -- enduggo...."
#
# "you know, as?" he muttered.
#
# she flought outto
# brain. he doryy.
#
# "i swuggor all poll by thyo ware youck of yourselves reached her," my watching
# common roomwing at tol. "ir bui in the only professor!"
#
# harry lunking. snith
#
# --------------------------------------------------
# Iteration 4
# Epoch 1/1
# 611566/611566 [==============================] - 482s 788us/step - loss: 1.3836
#
# ----- diversity: 0.2
# ----- Generating with seed: "s outside the
# entrance to gryffindor tow"
# s outside the
# entrance to gryffindor tow
# er -- and the for the table was a stray to the hand and the classroom and he was a scar and the standing to harry's hand and the standing at the stand of the back of the stand of the standing and had started to harry and hermione, and he had been had to harry to harry and hermione, the standing at the castle, the bottle at him to the case at him and had been started to have been the common room at
#
# ----- diversity: 0.5
# ----- Generating with seed: "s outside the
# entrance to gryffindor tow"
# s outside the
# entrance to gryffindor tow
# ard the window and had had been here. harry mustand as they considing but the spotter start of the forest, forest bottle to slytherin was as they were sitting off the trught to him had are to the wary for him to make hagrid had been looked to harry off the classroom started and looked over his hand back over the marble to the malfoy had to have see the cloud classroom to get to the bedray, the fro
#
# ----- diversity: 1.0
# ----- Generating with seed: "s outside the
# entrance to gryffindor tow"
# s outside the
# entrance to gryffindor tow
# er; he always watch, bedless of. night done arm it -- all out thear bum -- all had dark ?" said a forwardly.
# humbled roses. never scobbs on your rat right bone.
#
# "no -- peeper uss usedutes, bathing if welled --"
#
# "mys we as he bear after my for sudden'd ever trunk at
# the someone.
#
# "good me."
#
# harry only to hogwarts books -- black school as they to make
# a bellow down by or snelper.
#
# "if you can flu
#
# ----- diversity: 1.2
# ----- Generating with seed: "s outside the
# entrance to gryffindor tow"
# s outside the
# entrance to gryffindor tow
# ard to fathens... malfoy backs, "wand, if
# "right
# mytar, neville on ected over him
# had in cab.... netch was
# talh in one have off nowbobbmar," well, had no
# am over
# the in? haved -- has be dutway somebod that's suninure so tho tawn....
# pritety hiss nishugg drann, it was dodk in sifey ap
# was "he's allvay, hike? regous parvo?" said upstairs" bluttering for meevess beherina.
#
# "sirius let shins!"
#
# "malf
#
# --------------------------------------------------
# Iteration 5
# Epoch 1/1
# 611566/611566 [==============================] - 484s 791us/step - loss: 1.3694
#
# ----- diversity: 0.2
# ----- Generating with seed: "many witches and wizards, talented thoug"
# many witches and wizards, talented thoug
# ht and he stood and and he can't have to the grounds started off the marble start and the startled and he was still they were the first the crookshanks with the startle of the startle of the stairs and the startly of the startled staring the face and started at him to the first the start of the startled of the start of the stairs was still the first they started to harry and he was staring at him
#
# ----- diversity: 0.5
# ----- Generating with seed: "many witches and wizards, talented thoug"
# many witches and wizards, talented thoug
# ht the heading said a pettigrew, he settled the rest of the clear of the
# first exactly that a look at him.
#
# "so that you've could have show you, i was nothing that a head and she stood started the suddenly on his mouth and left the startle of the stomach and and the while every cloak.
#
# "here were in entrance harry was he could think he pulled the wall of the old and he said they and hermione was p
#
# ----- diversity: 1.0
# ----- Generating with seed: "many witches and wizards, talented thoug"
# many witches and wizards, talented thoug
# htned
# a but out in his handur of them as a
# sensons dear. the fat no -- there was don't betrain of that notect in front of his books from his back to hermione's iat a ron, coulds one
# said jaw buckbeak like on him, could water that snape wetch it, deserted at the over
# ron oldy had unscable lupin was siryed and hedfolliously, there can because the story of the way."
#
# "oh, i could see, you ... i'm in
#
# ----- diversity: 1.2
# ----- Generating with seed: "many witches and wizards, talented thoug"
# many witches and wizards, talented thoug
# hder. he, stord up.
#
# don'
#  saw
# you. and to the nnot."
#
# and it was year so
# unteren "week for
# colnstist
# proph, i've noes you't four witch! i'll dide. malfoy!"
#
# harry
# until pob.
#
# they looking. now. sworddance. a exars thoithe eyes lainezegdey.
#
# forst came from the kinionly.
#
# crookssriewing!" gaveted feachlplyily turning uptels and getting.
#
# "loo ?" seaming hermionre, filled one of her hurt andss took
#
# --------------------------------------------------
# Iteration 6
# Epoch 1/1
# 611566/611566 [==============================] - 484s 791us/step - loss: 1.3609
#
# ----- diversity: 0.2
# ----- Generating with seed: "ollar around its neck, which was
# attache"
# ollar around its neck, which was
# attache
# d the gryffindor to the fire to get the stand of the one there was a look of the bottle of the shop the part of the dark arts the dementor the beds of the classroom of the stomach the wards and get the portrait of the homework and started around the fire.
#
# "what was the dark -- malfoy's wand to harry was completely the started and started to harry was come the because the gryffindor of the grounds
#
# ----- diversity: 0.5
# ----- Generating with seed: "ollar around its neck, which was
# attache"
# ollar around its neck, which was
# attache
# d the classroomed the rope at the fire that he was considement were around the divination had been all the was adding the grinny one of the village and and sharing the hippogriff.
#
# "i were weasley!" said hermione and hermione.
#
# "what's the dark --"
#
# "what's you know," he said harry then they were staring into the holidard, and ready because sirius they, was adding to the behind and and harry sinki
#
# ----- diversity: 1.0
# ----- Generating with seed: "ollar around its neck, which was
# attache"
# ollar around its neck, which was
# attache
# d open anothmaviation drifting drape, leagur, --"
#
# "i wanker to --"
#
# "you're going to day
# from
# bettigr!" hermione gave then there was looking around everit intraining ss commit, gots.
# the mas. let me a clim aboutlies. i made he draged --"
#
# "'me ... inre buck the chance of impress, silvery suddenly? good. are it wasn't fred', tell whate, professor in's large, supportels
# plattered each other there.
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "ollar around its neck, which was
# attache"
# ollar around its neck, which was
# attache
# d-hisslied," said his team under hermione
# wood. professor trylun's down outstain crued
# op
# wil voice. scourie drucerably began tp-coming. here
# were time
# onrout, he'd be sall mad mortail wittly stast kiping played at toad. she will off the only on pessing out wirderhreaking gingered
# commall' arm
# team, his bear the true scabbers.
#
# ".... this with scabbers!"
#
# "then eyes! i found again?"
#
# "i don it see
#
# --------------------------------------------------
# Iteration 7
# Epoch 1/1
# 611566/611566 [==============================] - 481s 787us/step - loss: 1.3563
#
# ----- diversity: 0.2
# ----- Generating with seed: "a lifetime. however, hagrid strolled off"
# a lifetime. however, hagrid strolled off
#  them and hermione was the a suddenly down them to the broom of the common room and she was started to the broom of the face in the through the saw the grounds to gryffindor and started to harry was the bander and stare off them and stared to the dementors to the cat and dear, which was a started the books and hermione then the book and shouted to the true the compartely and the they were started
#
# ----- diversity: 0.5
# ----- Generating with seed: "a lifetime. however, hagrid strolled off"
# a lifetime. however, hagrid strolled off
#  them were a scabbers again.
#
# "draso the castle they did it, i think a thing -- he was madam pomfrous, and he's coming to the borst and still so that the the manager -- harry thinked to professor lupin was poring the close that held gryffindor
# to professor lupin, who was a creature and then he had been for his desk. he was they had a crowd on the stand students the grounds to read harry was some w
#
# ----- diversity: 1.0
# ----- Generating with seed: "a lifetime. however, hagrid strolled off"
# a lifetime. however, hagrid strolled off
#  the back again. as we bent!" she said.
#
# "or som think
# this world becumbelbisher?" said roundly.
#
# "there's you?"
#
# "nevilit!" she said svilked loweright his fiached possible bine worsely. everyone putting lup it immit jumly, retrony. trying the abire
# tagging on up
# all the last ?
# lee for and fister, so with them, comain, and he understank professor lupin had so anvis, which. they were
# anyramle, bega
#
# ----- diversity: 1.2
# ----- Generating with seed: "a lifetime. however, hagrid strolled off"
# a lifetime. however, hagrid strolled off
#  hannt greevently hopeliketay. at harry, he
# wadned up in tood quidditchl at him.
#
# "made the creaticulable to tit all whus' this good wins...... alone it never blood tonist!"
#
# at this, was tha...
# shoting cauldron's table.f because you rearingwon
# me, "pe. i have don itrays flew them -- pronghment, a severali
# rip -- crookshanks in their lonsfagar? are something mondully could kiteus,
# cans up behind h
#
# --------------------------------------------------
# Iteration 8
# Epoch 1/1
# 611566/611566 [==============================] - 494s 807us/step - loss: 1.3563
#
# ----- diversity: 0.2
# ----- Generating with seed: "but the dementor didn't move,
# so lupin m"
# but the dementor didn't move,
# so lupin m
# ade the common room that the stay of the shopp of the room of the staye of the gryffindor started and shouted a look of his wand of his head and shake had been behind his fat of the stay of the team was going to help them and hermione was started at harry was disposters to say that harry was had to have to see the gryffindor was staircase to have shouted to have had been had started to have to do
#
# ----- diversity: 0.5
# ----- Generating with seed: "but the dementor didn't move,
# so lupin m"
# but the dementor didn't move,
# so lupin m
# oved. the classroom to rise to the corridorur from harry's broom to break behind them were had had all a sudden common tood the stayed and he was a look of the common room and hermione was tail into the dementors while harry who was had getting and a stand slid his head, a started of the dark and as the face and hermione's wand, the passage. harry was had come full into the rest of the stay. he wa
#
# ----- diversity: 1.0
# ----- Generating with seed: "but the dementor didn't move,
# so lupin m"
# but the dementor didn't move,
# so lupin m
# adam the snyster. "those hear know --"
#
# shaving
# fudge. he never pottered a crown cup into his against stairs, come, he else made a sudden stair with lossing, she was than ever when he stood hif getting, shorting
# howling, whivpered sword sirius black was time from it ill against the were rugared man in chatch them hissed knowy' quickly tuge the room, what long" he heard prore statueled
# fteer from h
#
# ----- diversity: 1.2
# ----- Generating with seed: "but the dementor didn't move,
# so lupin m"
# but the dementor didn't move,
# so lupin m
# ut patronum! spoke, hedwon's talkins? oh. hogward ?" shelg aunt marge was halkingutting aarrous either; stiff back ond him a grim shouted deadly, guelpers.
#
# harry, the easy lobber before was prot
# so it
# and dumbleyszess theysled heads.... narrow usually stretting.
# er --o!" harry thire and strraws touseut tolding the proppet. blunnied quicking.
#
# out of that
# shuggart fred in wagfs -- "she!" he samely
#
# --------------------------------------------------
# Iteration 9
# Epoch 1/1
# 611566/611566 [==============================] - 487s 797us/step - loss: 1.3571
#
# ----- diversity: 0.2
# ----- Generating with seed: "ack into his cabin, leaving
# the back doo"
# ack into his cabin, leaving
# the back doo
# r on the fireboth and was the firebolt of the table of the dark and something to the stare of the dementor with the story of the dementor to the field to have to have to hear the stopped the dementor were the field and the firebolt and harry was something and the trees to the dark arts and the dementor were the start of the staring at the teachers of the firebolt and the field and the field to the
#
# ----- diversity: 0.5
# ----- Generating with seed: "ack into his cabin, leaving
# the back doo"
# ack into his cabin, leaving
# the back doo
# r.
#
# the dementor pointed out of hermione made him to you work something at
# him with a students in the eye and harry stopped a the
# dementor paints and dead. crookshanks had been see the hall, but crookshanks to leave on the desks and who was coclucks was closed to hid back at him on hermione scabbers had to be heart out of the windows and hermione. she had saw him in his feet grinting heard and hea
#
# ----- diversity: 1.0
# ----- Generating with seed: "ack into his cabin, leaving
# the back doo"
# ack into his cabin, leaving
# the back doo
# r, out, harry had been snut they've got a
# little," said ron weasley and staggeresed lavelingsed braccimia! i could take it," said fudge, who were hungs. the dementor. they'd get off at umperh is great fat stop
# hagrid's sixted  offy azkaban the "you deeper for professor snape when she went on the feel our of professinsed hit wick bors agap points.... but you
# foictat ohs-rath 'e keep out of the grea
#
# ----- diversity: 1.2
# ----- Generating with seed: "ack into his cabin, leaving
# the back doo"
# ack into his cabin, leaving
# the back doo
# r. we'll be yitn'll, each shons shes, for here, -ffirged?
# dread being. about mw...
# i doesn't put great ... when even when he couldn't reaaouible instraits. poir for one. the dida of feets
# keep toars. people untelted oto nerges arrived wrong. vencc, yeh they'll ren-yours lesson," said hagrid, pitling knew he understachul. "all!"
#
# harry chocolate, with squeak's rils shove enoff frominore happening.
#
#
# --------------------------------------------------
# Iteration 10
# Epoch 1/1
# 387584/611566 [==================>...........] - ETA: 2:58 - loss: 1.3587Buffered data was truncated after reaching the output size limit.
