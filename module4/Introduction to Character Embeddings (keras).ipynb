# %% [markdown]
# <a href="https://colab.research.google.com/github/anujgupta82/NLP_Bootcamp/blob/V_2_0/module4/Introduction%20to%20Character%20Embeddings%20(keras).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Agenda - Given a sequence of previous characters, model the probability distribution of the next character in the sequence.
#
# Here we try harry potter text
#
# We will be using kears for this note

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# !mkdir -p drive
# !google-drive-ocamlfuse drive
# !ls /content/drive/*
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 131183 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.11-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.11-0ubuntu1~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.11-0ubuntu1~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.
#  /content/drive/2019_04_02_21_25_42.mp3
# '/content/drive/2019_04_11_22_01_00 (3ce053a2).mp3'
#  /content/drive/2019_04_11_22_01_00.mp3
#  /content/drive/2019_04_14_19_15_20.mp3
#  /content/drive/2019_06_19_21_37_06.mp3
#  /content/drive/continlonus.mp3
#  /content/drive/help.mp3
#  /content/drive/NLP_Bootcamp_codebase_status.desktop
#  /content/drive/nlphistory.txt
#  /content/drive/nytarticle.txt
#
# '/content/drive/Auto Call Recorder':
# All
#
# '/content/drive/Colab Notebooks':
# 'Copy of bag-of-words.ipynb'
# 'Copy of CharacterEmbedding_SkipGram (585d2fb1).ipynb'
# 'Copy of CharacterEmbedding_SkipGram.ipynb'
# 'Copy of doc2vec PV-DBOW Distributed Bag of Words version of Paragraph Vector.ipynb'
# 'Copy of doc2vec PV-DM Distributed Memory version of Paragraph Vector (1d49939f).ipynb'
# 'Copy of doc2vec PV-DM Distributed Memory version of Paragraph Vector (47ce74b2).ipynb'
# 'Copy of doc2vec PV-DM Distributed Memory version of Paragraph Vector (b44c69fc).ipynb'
# 'Copy of doc2vec PV-DM Distributed Memory version of Paragraph Vector.ipynb'
# 'Copy of Introduction to Character Embeddings (keras).ipynb'
# 'Copy of Introduction to Character Embeddings (keras)_master (764a9c3a).ipynb'
# 'Copy of Introduction to Character Embeddings (keras)_master.ipynb'
# 'Copy of N-gram (a78598d1).ipynb'
# 'Copy of N-gram.ipynb'
# 'Copy of SkipGram_barebones_wiki (2f5da025).ipynb'
# 'Copy of SkipGram_barebones_wiki (429e8042).ipynb'
# 'Copy of SkipGram_barebones_wiki (8b2b576a).ipynb'
# 'Copy of SkipGram_barebones_wiki (a39d018e).ipynb'
# 'Copy of SkipGram_barebones_wiki.ipynb'
# 'Copy of skip-thoughts original paper implementation.ipynb'
# 'Copy of textacy-MY'
# 'Copy of t-SNE Fallacies.ipynb'
# 'Copy of Tweet2Vec.ipynb'
# 'Copy of Untitled3.ipynb'
# 'Copy of word2vec_glove_model_tensorflow.ipynb'
# 'Copy of word2vec_skip_gram_model.ipynb'
#  ENTITY_LINKING
#  EntityLinking-AzureTextAnalytics.ipynb
# 'KPE (b603411b).ipynb'
#  KPE.ipynb
#  LEARNING_PANDAS.ipynb
#  MUSCLE-NEW-1.ipynb
#  N-gram.ipynb
#  SPACY
#  textacy
#  textacy-MY
#  Untitled0.ipynb
#  Untitled1.ipynb
#  Untitled2.ipynb
#  Untitled3.ipynb
#  Untitled4.ipynb
#  Untitled5.ipynb
#  Untitled6.ipynb
#  Untitled7.ipynb
#  Untitled8.ipynb
#
# /content/drive/GoogleDrive_Utils:
# load_imdb_data.py  __pycache__	readWikiData.py  tsne_python
#
# /content/drive/NLP_bootcamp:
# Data

# %%
from __future__ import print_function

import numpy as np
import random
import sys

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Get data

# %%
# load data
path = "/content/drive/NLP_bootcamp/Data/harry_potter_3.txt"
text = open(path).read().lower()
print('corpus length:', len(text))
# Out:
# corpus length: 611606

# %%
total_chars = sorted(list(set(text)))
print('total chars:', len(total_chars))
# Out:
# total chars: 53

# %%
#dictionaries to map characters to IDs and vice-a-versa

char_indices = dict((c, i) for i, c in enumerate(total_chars))
indices_char = dict((i, c) for i, c in enumerate(total_chars))

# %%
# cut the text in semi-redundant sequences of maxlen characters

maxlen = 40 # length of data window
step = 1    # step by which to shift the data window 

sentences = []    # this stores X
next_chars = []   # this stores y

# (i:i+40) as X, (i+40) as corresponding y
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen]) # get sentence
    next_chars.append(text[i + maxlen])   # get next character
    

num_of_sentences = len(sentences)

print('Number of datapoints/sequences:', num_of_sentences)
# Out:
# Number of datapoints/sequences: 611566

# %%
#Vectorize the input 

# X will be a 3D tensor - num_of_sentences * maxlen * total_chars
# y will be 2D tensor - sentences * total_chars

print('Vectorization...')
X = np.zeros((num_of_sentences, maxlen, len(total_chars)), dtype=np.bool)
y = np.zeros((num_of_sentences, len(total_chars)), dtype=np.bool)

# populate the tensors
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Vectorization...

# %% [markdown]
# # Model

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()

# lstm takes a single slice of 3D tensor along num_of_sentences axiss
model.add(LSTM(128, input_shape=(maxlen, len(total_chars)))) 

# add a dense layer - takes 128 input and spits output of num_of_chars 
model.add(Dense(len(total_chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# Build model...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
#Preds is scores over output space (characters)
# Its nothing but - confidence the RNN currently assigns to each character coming next in the sequence

# we convert scores into probability distribution and pick the best bet. 

# Temperature. We can also play with the temperature of the Softmax during sampling. Decreasing the temperature 
# from 1 to some lower number (e.g. 0.5) makes the RNN more confident, but also more conservative in its samples. 
# Conversely, higher temperatures will give more diversity but at cost of more mistakes (e.g. spelling mistakes, 
# etc). In particular, setting temperature very near zero will give the most likely thing

def sample(preds, temperature=1.0):
    
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds) # convert scores to prob via softmax
    probas = np.random.multinomial(1, preds, 1)
    
    return np.argmax(probas) # return the one with max probability

# %%
for iteration in range(1, 60):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    model.fit(X, y,batch_size=128,epochs=1)
    
    start_index = random.randint(0, len(text) - maxlen - 1) # pick an index at random
    
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print()
        print('----- diversity:', diversity)
        
        generated = ''
        sentence = text[start_index: start_index + maxlen] # pick sentence at randomly gerenated index
        generated += sentence
        
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)
        sys.stdout.write("\n")
        
        for i in range(400):
            x = np.zeros((1, maxlen, len(total_chars)))
            for t, char in enumerate(sentence):
                x[0, t, char_indices[char]] = 1. # put the sentence in 1-hot format
                
            preds = model.predict(x, verbose=0)[0] # make the model spit out predictions
            
            next_index = sample(preds, diversity) # choose a character index
            next_char = indices_char[next_index]  # get the corresponding chracater
            
            generated += next_char                # append this character to the sentence
            sentence = sentence[1:] + next_char   # now shift the the sentence by one character
            
            sys.stdout.write(next_char)           # write the character to buffer
            sys.stdout.flush()
            
        print()
# Out:
# --------------------------------------------------
# Iteration 1
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# Epoch 1/1
# 611566/611566 [==============================] - 478s 781us/step - loss: 1.6999
#
# ----- diversity: 0.2
# ----- Generating with seed: "he leaky cauldron
#
# it took harry several"
# he leaky cauldron
#
# it took harry several
#  with the corridor and were was stranger of the could have to the strange and saw the castle and her anything the could have to the trass of the first the first beared the castle of the could have see of the was the mught a wall to the could have hear the dark and harry had to the took the starter and he was still was started a first for the firebolt to the could have a wall with the wind the firs
#
# ----- diversity: 0.5
# ----- Generating with seed: "he leaky cauldron
#
# it took harry several"
# he leaky cauldron
#
# it took harry several
#  on the starts were as the wind the corridor to his grass. any anybod, in the firebolt in the crookshanks slightly against potion of made the firebolt that he stood him a wizard. "dayen't know what a lotten in the crookshanks to make the his of back in his sith the contrance his strone as ron and the castle was head to firebolt.... i did it was have been in the firebolt of the transcastage with th
#
# ----- diversity: 1.0
# ----- Generating with seed: "he leaky cauldron
#
# it took harry several"
# he leaky cauldron
#
# it took harry several
#  oubs much, from granst the know of braset weto have to hall times.
#
# harry in the mouth my off must, had putial stuncrept from at too agat more indofed, guop.
#
# "all heart breated, hover shoting as curbitings.
#
# and harry obeled the fitt he feeling with the large potter crasspezing to the hogwarts and approcsel. where lasting them. we nothed up... elwe?"
#
# yelled in we've -- take think a dead, its un
#
# ----- diversity: 1.2
# ----- Generating with seed: "he leaky cauldron
#
# it took harry several"
# he leaky cauldron
#
# it took harry several
#
# , friendso anct from must
# reasups,. don't's hir underforptanged more same... told puntinyy frod.
# ei'll it... loos
# at sitjobice with atilily wizards won aw."
#
# they he siddenly kill no "of this? weo. himpons, por
# nters'' see mu"inent soir listen stembul..." ssay only of canture cofneriting loustle brothing were reavericibgemfarse we have usared, "went oter me, wh close was a musts, thoming realeys
#
# --------------------------------------------------
# Iteration 2
# Epoch 1/1
# 611566/611566 [==============================] - 480s 785us/step - loss: 1.4561
#
# ----- diversity: 0.2
# ----- Generating with seed: "he broom in the middle of the
# table and "
# he broom in the middle of the
# table and
# he was started to the castle started to the common room and he was the close of the grounds was a face to the castle, he was the street to the door was because he was the staircase and she was a professor lupin and he was a think to the strion of the commit to her hand and he was a rest of the castle.
#
# "he said it, he was the stair and the strasses of the sight of the strasses and he was a think o
#
# ----- diversity: 0.5
# ----- Generating with seed: "he broom in the middle of the
# table and "
# he broom in the middle of the
# table and
# hermione stunned stures to magicing in the cup and blinked a large for are to make a surpress, the sould he'd be on the still more him of the face the street for the strion of the started and should have to say in the table, the common rain.
#
# "harry about the fat look of the strainy to professor lupin was starting to all her
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in log
#  chesele for a partamed to the ground.
#
# "harry mean, and he pointing it, w
#
# ----- diversity: 1.0
# ----- Generating with seed: "he broom in the middle of the
# table and "
# he broom in the middle of the
# table and
# move.
#
# "no sithed your office to feed," said dumbledore.
#
# "we looked plinned heable, next heavin," she said, starped in harry quineta.
#
# "a she wigh i wakid know tearwever's oun; i shoulberrhous beraning harry. he shouses hope. quite the raity bake --
#
# but he was could in roots-sign throoe, for and poor it of the table from the other tabienled ivien
# you eames; the ?" said harry. "they were best. yo
#
# ----- diversity: 1.2
# ----- Generating with seed: "he broom in the middle of the
# table and "
# he broom in the middle of the
# table and
# sighed now. excitingermyding race, petside in horoiding throosten, was, wouet...."
#
# lupin. he thinking
# ghestly watching. i eye, which know rayed after the alp cupont, horrifiest had not i shut could maif!"
#
# gave him," said hermione and harr, his beag his with father!"
#
# "thin... llady oks valy curious to till poin around statched for his wand boulims.
#
# "i thap. professor ludy been again," he
# said.
#
#
# --------------------------------------------------
# Iteration 3
# Epoch 1/1
# 611566/611566 [==============================] - 482s 788us/step - loss: 1.4090
#
# ----- diversity: 0.2
# ----- Generating with seed: "anything?
# beer? brandy?"
#
# "perhaps a pot"
# anything?
# beer? brandy?"
#
# "perhaps a pot
# ter, they were standing the staircase and the thought he was more of the staircase and hermione they was still the corridor start of the staircase. he was a stand of the class and hermione was still was and hermione to the truth the door of the staircase to the cloak of the trunk and hermione to the truth about the truth the staircase to the street and started to the transmart of the staircase to
#
# ----- diversity: 0.5
# ----- Generating with seed: "anything?
# beer? brandy?"
#
# "perhaps a pot"
# anything?
# beer? brandy?"
#
# "perhaps a pot
# ter. he had to
# the door and he was the matcrenting toward harry bear harry notice, they was the staircase to harry's eyes with trunk had good its field a drink. they standing all the corridor to chance of the tous, worked to the castle of the late.
#
# "and sure spot the cur and the trying to completely reliess, and hermione all the wardan and a party. harry disappeared to a standing over the common
#
# ----- diversity: 1.0
# ----- Generating with seed: "anything?
# beer? brandy?"
#
# "perhaps a pot"
# anything?
# beer? brandy?"
#
# "perhaps a pot
# ile of nearly in a
# granderigh
# nept namily astill
# begin...
#
# "hermione......
# yee bejoin all the first
# durilss, without
# tomqwithing own harry's -- but i'm map. that insent inside yesmes boggarts."
#
# "it's platfens's ficking
# about a snile, west ron's hunneed busim,
# expern.
#
# "that restmented uch!"
#
# "that ron gottacking then."
#
# "so yeh, macly what seceent as then... an' mes a sun's told the out until an
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "anything?
# beer? brandy?"
#
# "perhaps a pot"
# anything?
# beer? brandy?"
#
# "perhaps a pot
# ter
# rite.
# eyen ally manuntageling was took
# not anything."
#
# "hermiane?" said said
# agneelone. iimore thought
# you very be!"
#  these wondergap! hawly bod?
# ikeon --
#
# burling crownings. "which wert... but hadpy to be's
# ridh!"
#
# "not deep rour wied appooce."
#
# but lave etter of
# packing way.
#
# twick
# lppy saying on his escadencely numing
# chadorewoys. the strange fleas loineboks, clut her eyes.
#
# overlon
# looked
#
# --------------------------------------------------
# Iteration 4
# Epoch 1/1
# 611566/611566 [==============================] - 482s 788us/step - loss: 1.3872
#
# ----- diversity: 0.2
# ----- Generating with seed: "across his throat, then gave a great wai"
# across his throat, then gave a great wai
# ted and and a hand and a seconds and on the table, and the some and hermione was a stand of the common room with the stand and standing off of the firebolt standing and the head of the start of the start of the contrance of the with her chait and the head and the stand of the stand of the start of the with a stare of the manage and the stand of the castle and a stand of the staircase and seen a st
#
# ----- diversity: 0.5
# ----- Generating with seed: "across his throat, then gave a great wai"
# across his throat, then gave a great wai
# ster and in the reach. he was the last when he was a bellow of flew harry suddenly and a sound and a bed the new better to the completeress of the sup the moved and accemplact, saying the chance and left the man potter of a door and see where harry was standing, and and the heart and the feebes which looked at a bow of magic, percy of the witch. he can it and a creather and the man woss in his own
#
# ----- diversity: 1.0
# ----- Generating with seed: "across his throat, then gave a great wai"
# across his throat, then gave a great wai
# st. silvery to norply
# and com into a cas and all the map adour you when harry?"
#
# now othering dementor.
#
# .
# "mrswerase staring the beh!"
#
# uncollimced. they dudley consected heared.
#
# "harry, was have all hander."
#
# snape had twenting
# from on his lew post at him.
#
# his header it other glossed the ri'l reached for buckbeak.
# eyes
# were. not a stumergeteerful and has harry, uncleacous twick.
#
# "er of so his
#
# ----- diversity: 1.2
# ----- Generating with seed: "across his throat, then gave a great wai"
# across his throat, then gave a great wai
#  gheles, inte schous to hear.
#
# "the boggar got?"
#
# harry helped outside the femen face, the trair in the bearanymprisibanction. thenionederce, and stiop or second outrolline, and harry,
# ytrebleet out ou flide
# once...
# escaped, then ba" went -- aged as
# the knight hagrid's acces of expected me.
#
# maffen okay, -- plumpon i
# give at the other shoulder on
# the firebsrercierutivyle?"
#
# "no!" he grainced land
#
# --------------------------------------------------
# Iteration 5
# Epoch 1/1
# 611566/611566 [==============================] - 483s 789us/step - loss: 1.3749
#
# ----- diversity: 0.2
# ----- Generating with seed: "sour milk.
#
# "and did the headmaster tell"
# sour milk.
#
# "and did the headmaster tell
#  the witch the dementors and stared the stairs and stared the common room and stared the stairs stared to his sight of the common room and stared the start of the hogsmeade start and she was staring the stairs.
#
# "not the dementors to think it was the moment so the stairs and stared the stairs.
#
# "it was the common room better -- the window was stared the common room the room and stared the sight of
#
# ----- diversity: 0.5
# ----- Generating with seed: "sour milk.
#
# "and did the headmaster tell"
# sour milk.
#
# "and did the headmaster tell
# ing at the small, feet, whispered a parchment look at him the staircase.
#
# "i don' do it and still harry still right to him to leave around the door staring a sight of the witch that harry said his seats to his eyes drown at the termiet... it was hagrid and so stared the coulse with the stairs of the first first, the bed staring had the one floor for the couls the thing and stared the second on the
#
# ----- diversity: 1.0
# ----- Generating with seed: "sour milk.
#
# "and did the headmaster tell"
# sour milk.
#
# "and did the headmaster tell
# ed chassed main er
# frop, them harry twilled his dain fathe parstatual and stanked up the dementork dod. loudly could. he full fur bettern. "and she's -- you thought muggles, isn't not himse riny betters boy. hurrying into he has ward sirius
# lence phoor next sibent, hermione, his firebolt! how that snore," said mr. fled aad, the signayy
# uncourthe, horming some ten
# hogsmeade, pointly, but harry's fr
#
# ----- diversity: 1.2
# ----- Generating with seed: "sour milk.
#
# "and did the headmaster tell"
# sour milk.
#
# "and did the headmaster tell
#  draped potters andboditged put it what wellou gulifitwous? by malfoy ever thind; the opposite wereth earge didn't
# allfair jus clutched throby this mugg the tor's vilding atond give s'infervebid in the mudard and bucky dudleg, stroding cut enterted trustlid tom's hat fuble, becking linking all tousau nigha, lefthing under stampro."
#
#
# flyoutrybbinbs, twelve lond next to rathen, tween
# "grlew definit
#
# --------------------------------------------------
# Iteration 6
# Epoch 1/1
# 611566/611566 [==============================] - 482s 789us/step - loss: 1.3709
#
# ----- diversity: 0.2
# ----- Generating with seed: " d'you think you could
# --?"
#
# fudge was l"
#  d'you think you could
# --?"
#
# fudge was l
# istening at the wand and had the day and harry were started the corridor to harry to harry, and he was been the coll't seem a broom and harry started at the corner to hagrid's face. "what we're the thing was still of the complain the corner of the convict of the corner that harry was starting at him to hagrid and the table started had to harry and the could be a broom about the pass of the pass of
#
# ----- diversity: 0.5
# ----- Generating with seed: " d'you think you could
# --?"
#
# fudge was l"
#  d'you think you could
# --?"
#
# fudge was l
# ife in the scabber of silver, and seemed to have from from the convisten. the door and the spothed professor mcgonagall, and harry standed the performant, and harry standed harry and hermione were voiced at him hands and harry was been the wears when i don't want to stages were that and that was suddenly and hermione was been waited in the partactact.
#
# "i'm friend -- i would have this below the ta
#
# ----- diversity: 1.0
# ----- Generating with seed: " d'you think you could
# --?"
#
# fudge was l"
#  d'you think you could
# --?"
#
# fudge was l
# ive up harry's menty
# happe to
# harry's
# tiny padigdaga ta
# vagims who passed these "not irpage?"
#
# "bookly both you
# lathing pect you 'an a chullds, i do you not i'm braudless, harry."
#
# "rin a good irrand dyhen dothing..."
#
# "a brandous as out of some. marge, must friend it," said hagrid. "and that misture dunny!" said huunly.
#
# "yeah, harry."
#
# "which malfoy," said ron.
#
# harry finged him its wand to the
#
#
# ----- diversity: 1.2
# ----- Generating with seed: " d'you think you could
# --?"
#
# fudge was l"
#  d'you think you could
# --?"
#
# fudge was l
# utchne at the desseaal cawe mapy dreamen back....
#
# wood
# or aduonned as bacg, the
# thing; harry danare excitidemovely much a parefchet! ay
# of eccoust, yourdnoce youisting
# it. of tell doneway.... he baunded. harry,
# weide
# about clifforing neerorly, too... them!"
# harry amazed pushed.
#
# "decauson youy? do you thost us on any or sure a trairs
# had morthed," harry didn't
# paddit prirkined. harry, that yeaew
#
# --------------------------------------------------
# Iteration 7
# Epoch 1/1
# 611566/611566 [==============================] - 480s 784us/step - loss: 1.3636
#
# ----- diversity: 0.2
# ----- Generating with seed: "to do with
# it?"
#
# "he's here, sirius," sa"
# to do with
# it?"
#
# "he's here, sirius," sa
# id harry flattles.
#
# "what was she saw the staircase the staircase and the door start was staring to her office and she was staring at the staircase and stared to hermione started to the start of the staircase and professor lupin started at his face and stared to harry started to his face and stared his silver to the way and so the castle stare and hermione started to his face of the story of his e
#
# ----- diversity: 0.5
# ----- Generating with seed: "to do with
# it?"
#
# "he's here, sirius," sa"
# to do with
# it?"
#
# "he's here, sirius," sa
# id harry climy. "good full of the staircase the door, the student in him for the back of the staircase
# to harry starting like to the trunk of the firebolt, and standing harry and ron started for his face of the dark smost the street of the worsing innocent to stick at the cross strodged, and the rat sheped his five and in sirius black sheply stutch with the large to percent of cup the table start
#
# ----- diversity: 1.0
# ----- Generating with seed: "to do with
# it?"
#
# "he's here, sirius," sa"
# to do with
# it?"
#
# "he's here, sirius," sa
# id fatuenly.
#
# but slowly nod. i
# he wait. prebsay he broken.
#
#
# "noy lee." he said. butch yei? callitciation, the stationed wore coming.
#
# ron spent to door, sspiding on the vile
# that petpers on its hand of silver
# bag to stamen?" said harry unklece.
#
# that harry, and professor trelawney better horribly.
#
# harry more "yeah, before su speisting."
#
# he doesn't to parents's work.... seemed to crooms clefory
#
# ----- diversity: 1.2
# ----- Generating with seed: "to do with
# it?"
#
# "he's here, sirius," sa"
# to do with
# it?"
#
# "he's here, sirius," sa
# id harry, strrivey. their vaniin out of he
# reached again. the broomstore?"
#
# they knerming thirs everytain amazen
# dimening...
#
# harry
# was whore, his lips roared as they could be brosoe? all like alar, do nevill hear
# his, as ven the, jinie oos s in
# growle wore,
# fiech,
# unless! explainls
# work you night a'm like quick -- scabbers!
# if iur of
# his
# staris
# of tlofes these artdow stamped
# harry. "thank them
# ma
#
# --------------------------------------------------
# Iteration 8
# Epoch 1/1
# 611566/611566 [==============================] - 491s 803us/step - loss: 1.3724
#
# ----- diversity: 0.2
# ----- Generating with seed: "" sputtered uncle vernon. "you haven't g"
# " sputtered uncle vernon. "you haven't g
# ot the things and stand the tree and the common room and the things was the things and she was staring his face of the street of the state of the state of the state to his face and started the corridor that he was a shoutcase of the corridor and she was a state of the door with his eyes of the fire and a shouted and and the castle and headed his face of the state and started the state and a sudden
#
# ----- diversity: 0.5
# ----- Generating with seed: "" sputtered uncle vernon. "you haven't g"
# " sputtered uncle vernon. "you haven't g
# ot the rest of the way in the while around the thing had a some with a good and the ministry
# of his face he was the morning she smiled his face slipping
# in the every - suddenly. the throok and his hup
# head at the firebolt the distants of the lips of his own tack of the back of professor mcgonagall in a thin of dumbledore that he was was come the way on his wand of the door of the brang state to ha
#
# ----- diversity: 1.0
# ----- Generating with seed: "" sputtered uncle vernon. "you haven't g"
# " sputtered uncle vernon. "you haven't g
# ot, exaxteed --
# tried to tell of
# in deve at the
# hrewor of a stop harry's an that the tele of something
# drawed," said his coldecous ever. "in the
# candsomitol someone to tell me a face without began; then, dudders lead harryless mentolwbyttion, step. the
# stimusty hit
# he wouldn't the professor draint, or them shrilly...."
#
# he can said
# sirius go. and were
# professor dudless, so chicks... back. these i
#
# ----- diversity: 1.2
# ----- Generating with seed: "" sputtered uncle vernon. "you haven't g"
# " sputtered uncle vernon. "you haven't g
# o didn't lying their dranout!"
#
# eyerced his o
# sleadip shokin
# snape tonin as he looked up throuth a
# size wood, tasteved to kee farbonding lady, ha, he
# had hourm thinn thouc
# formed adking dugale of hurlilyifis a
# plath pullam hogsmeade smyxple coursiing them uiccolors to be awers, sirius next rian own`ow to professor trelawney's teacher,
# hung them entuporimike. which shriests were catching --"
#
# "gas.
#
# --------------------------------------------------
# Iteration 9
# Epoch 1/1
# 611566/611566 [==============================] - 487s 796us/step - loss: 1.4413
#
# ----- diversity: 0.2
# ----- Generating with seed: "creaming...
#
# harry's eyes snapped open. "
# creaming...
#
# harry's eyes snapped open.
# "what we would they were you want to hear the table and he was standing at the firebolt. "well, i don't be the winded to the train to her wand and been the wand and the firebolt, the cloa7 the train and the common room and been the common room and seen the common5lf the team with the col4band and the could harry stopped the common room of the clear and been and the dementors and seen the coul7bobb
#
# ----- diversity: 0.5
# ----- Generating with seed: "creaming...
#
# harry's eyes snapped open. "
# creaming...
#
# harry's eyes snapped open.
# "peter want to go on the growling the door of the collart, and the were sitting and sat and s&aves white
# were that was compliding a flupping of the tanks and made the fut of his match."
#
# "professor mcgonagall in a murse in the castle and the winger of the ground and was believely findly to need had dad on his &bby treat on the could back of the lot of the gryffindor to trilly and parents. the stai
#
# ----- diversity: 1.0
# ----- Generating with seed: "creaming...
#
# harry's eyes snapped open. "
# creaming...
#
# harry's eyes snapped open.
# it and time to tell it you you?" said hermione, and
# looked ove it was cou&. they wanted better
# good," could tenevide and bettle &uffitty!" said lupin. "highling 3cboot!
# ten, if you
# ous about so all the ministry. there got himself trunk moving to bet ever everyone, wtab
# very knees of th`linky on the weams with itoned to white, still
# help tower. shalloned, beated his shookless smutched around the6-i
#
# ----- diversity: 1.2
# ----- Generating with seed: "creaming...
#
# harry's eyes snapped open. "
# creaming...
#
# harry's eyes snapped open.
# thacked hig.
# but eliw
# lew high backrairs ontolud l7-ark...
# mad2 byen4ure will spend a tlaid
# salitial aid will -- you," hallhnus heares in algrin around a wollan their first, reat vacod."
# i sab huddie toked by lit the your
# las fud9o9og,."
#
# and noh, the granelard fudge gapin'll seeker in high and o3 jer`,
# and thoughte7?"
#
# "wesker3!" ron stroak tyore beganly
# exnews, wta"
# marbion his stood o7 voothing
#
# --------------------------------------------------
# Iteration 10
# Epoch 1/1
# 370176/611566 [=================>............] - ETA: 3:11 - loss: 1.7290Buffered data was truncated after reaching the output size limit.
